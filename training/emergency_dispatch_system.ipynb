# %%
# !pip install -q unsloth trl datasets requests pydantic matplotlib uvicorn fastapi openenv-core
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 35.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 47.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.6/174.6 kB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.6/728.6 kB 49.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.3/253.3 kB 24.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 131.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.9/421.9 kB 40.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 122.6 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/Ignatius-Nobel/Emergency-Dispatch-System.git
# %cd Emergency-Dispatch-System
# !git log -1 --oneline
# Out:
# Cloning into 'Emergency-Dispatch-System'...
# remote: Enumerating objects: 196, done.
# remote: Counting objects: 100% (196/196), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 196 (delta 97), reused 160 (delta 62), pack-reused 0 (from 0)
# Receiving objects: 100% (196/196), 321.14 KiB | 20.07 MiB/s, done.
# Resolving deltas: 100% (97/97), done.
# /content/Emergency-Dispatch-System
# 1f0ad04 (HEAD -> main, origin/main, origin/HEAD) fix(training): fix syntax error in obs_to_prompt and add unit fallback in parse_action

# %%
 # !python3 training/train_dispatch.py --task mixed --steps 50 --episodes 10
# Out:
# [OK] OpenEnv server running on port 8000
# [..] Building dataset (10 episodes)...
# [OK] Dataset ready: 10 rows
# [..] Evaluating random baseline...
# [OK] Random agent mean episode score: 1.2652
# [..] Loading model: unsloth/Qwen2.5-7B-Instruct
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.4.8: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 112kB [00:00, 165MB/s]
# ...
# Fetching 2 files: 100% 2/2 [01:32<00:00, 46.30s/it]
# ...

# %%
from IPython.display import Image
Image('/content/Emergency-Dispatch-System/training/reward_curve.png')

# %%
from IPython.display import Image
Image('/content/Emergency-Dispatch-System/training/loss_curve_base.png')

# %%
 # !python3 training/train_dispatch.py --task mixed --steps 300 --episodes 200
# Out:
# [OK] OpenEnv server running on port 8000
# [..] Building dataset (200 episodes)...
# [OK] Dataset ready: 200 rows
# [..] Evaluating random baseline...
# [OK] Random agent mean episode score: 1.3828
# [..] Loading model: unsloth/Qwen2.5-7B-Instruct
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.4.8: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights: 100% 339/339 [00:26<00:00, 13.04it/s]
# ...

# %%
from IPython.display import Image
Image('/content/Emergency-Dispatch-System/training/reward_curve.png')

# %%
from IPython.display import Image
Image('/content/Emergency-Dispatch-System/training/loss_curve.png')
